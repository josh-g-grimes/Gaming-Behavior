# %%
#Import scikit-learn dataset library
from sklearn import datasets
import pandas as pd


#Load dataset
gb = pd.read_csv('online_gaming_behavior_dataset.csv')

# %%
gb = gb[(gb['EngagementLevel']=='High')|(gb['EngagementLevel']=='Low')]
gb = pd.get_dummies(gb, dtype = float)
gb = gb.drop(['PlayerID', 'PlayTimeHours', 'Gender_Male', 'GameGenre_Strategy', 'GameDifficulty_Easy', 'EngagementLevel_Low'], axis=1)
gb
# Out:
#        Age  InGamePurchases  SessionsPerWeek  AvgSessionDurationMinutes  \
# 2       22                0               16                        142
# 5       37                0                2                         81
# 6       25                0                1                         50
# 9       38                0               13                         95
# 10      17                0                8                         95
# ...    ...              ...              ...                        ...
# 40026   33                1               12                        166
# 40027   17                0                6                         24
# 40028   36                0                4                         34
# 40030   44                0               19                        114
# 40031   15                1               10                        176
#
#        PlayerLevel  AchievementsUnlocked  Gender_Female  Location_Asia  \
# ...

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X = gb.drop('EngagementLevel_High', axis=1)
y = gb['EngagementLevel_High']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9394966118102613
# Precision: 0.9416707859614434
# Recall: 0.93519882179676

# %%
#Create a svm Classifier
clf_polynomial = svm.SVC(kernel='poly') # Linear Kernel

#Train the model using the training sets
clf_polynomial.fit(X_train, y_train)

#Predict the response for test dataset
y_pred_polynomial = clf_polynomial.predict(X_test)

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_polynomial))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred_polynomial))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred_polynomial))
# Out:
# Accuracy: 0.9419167473378509
# Precision: 0.9512807634354595
# Recall: 0.9297987236131566

# %%
#Create a svm Classifier
clf_rbf = svm.SVC(kernel='rbf') # Linear Kernel

#Train the model using the training sets
clf_rbf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred_rbf = clf_rbf.predict(X_test)

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_rbf))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred_rbf))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred_rbf))
# Out:
# Accuracy: 0.9428848015488868
# Precision: 0.9473422752111277
# Recall: 0.9361806578301424

# %%
#Create a svm Classifier
clf_rbf_c = svm.SVC(kernel='rbf', C=1000) # Linear Kernel

#Train the model using the training sets
clf_rbf_c.fit(X_train, y_train)

#Predict the response for test dataset
y_pred_rbf_c = clf_rbf_c.predict(X_test)

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_rbf_c))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred_rbf_c))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred_rbf_c))
# Out:
# Accuracy: 0.9407066795740562
# Precision: 0.9400785854616895
# Recall: 0.9396170839469808

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score

# %%
cm = confusion_matrix (y_test, y_pred_rbf_c)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
